# %% [markdown]
# ### Import Data and Merge

# %%
import pandas as pd
import numpy as np

em_s, em_e = "\033[1m", "\033[0;0m"

# %%
insider_decks = pd.read_csv("./data/insider_pitch_decks.csv").drop(columns = ["Unnamed: 0"]).dropna()
best_decks = pd.read_csv("./data/best_pitch_decks.csv").dropna(subset = ["Industry"])

display(insider_decks.head())
display(best_decks.head())
# Out:
#                             Local Link    Stage         Industry      Region
# 0        ./InsiderPitchPDFs/0xLabs.pdf  SeriesB          Fintech  N. America
# 1       ./InsiderPitchPDFs/100plus.pdf     Seed       Healthcare  N. America
# 2          ./InsiderPitchPDFs/10KC.pdf   Growth  Online learning  N. America
# 3          ./InsiderPitchPDFs/1906.pdf  SeriesA         Cannabis  N. America
# 4  ./InsiderPitchPDFs/1inchNetwork.pdf  SeriesB          Fintech  N. America
#        Name         Industry  \
# 0      Bolt             SaaS
# 1   Spotify            Music
# 2    WeWork         Proptech
# 3    AirBnB  Travel & Events
# 4  Facebook     Social Media
#
#                                          Description  \
# 0  Bolt is an innovative payment processing compa...
# 1  Spotify Technology S.A., together with its sub...
# 2  WeWork Companies Inc. operates as a real estat...
# 3  Airbnb, Inc., together with its subsidiaries, ...
# 4  Facebook, Inc. operates a social networking we...
#
#                                    Short Description  \
# 0  One-click checkout Bolt used this 12-page deck...
# 1  Spotify is a premium streaming service that gi...
# 2  WeWork is a commercial real estate company tha...
# 3  Airbnb is one of the world's largest marketpla...
# 4  Facebook is a social network that connects you...
#
#                                    Tags      Business Model Customer Model  \
# 0                                  SaaS                SaaS          B2B2C
# 1           Music, Entertainment, Audio  SaaS, Subscription            B2C
# 2  Proptech, Collaboration, Real Estate         Marketplace            B2B
# 3                       Travel & Events    SaaS, E-commerce            NaN
# 4                      Social Media, IT         Marketplace          B2B2C
#
#         Website Raised Year Raised        Stage        Investors  \
# 0      bolt.com  $393M        2021     Series D               VC
# 1   spotify.com  $100M        2012   Late Stage  Angel Investors
# 2    wework.com  $335M        2014   Late Stage        Corporate
# 3    airbnb.com  $600k        2008     Pre-Seed              NaN
# 4  facebook.com  $500k        2004  Early Stage    VC, Corporate
#
#                         PDF URL
# 0      ./BestPitchPDFs/bolt.pdf
# 1   ./BestPitchPDFs/spotify.pdf
# 2    ./BestPitchPDFs/wework.pdf
# 3    ./BestPitchPDFs/airbnb.pdf
# 4  ./BestPitchPDFs/facebook.pdf

# %%
import re
def standardize_text(x):
    return re.sub('[^0-9a-zA-Z]+', '', x.lower())

best_decks["Industry"] = best_decks["Industry"].astype(str).apply(standardize_text)
insider_decks["Industry"] = insider_decks["Industry"].astype(str).apply(standardize_text)

all_unique_industries = np.unique(np.concatenate((best_decks["Industry"], insider_decks["Industry"])))

# %%
insider_decks.rename(columns = {'Local Link': 'PDF URL'}, inplace = True)

common_columns = list(set(best_decks.columns).intersection(insider_decks.columns))

master_df = pd.concat((best_decks[common_columns], insider_decks[common_columns]))
display(master_df)
# Out:
#                Industry        Stage                              PDF URL
# 0                  saas     Series D             ./BestPitchPDFs/bolt.pdf
# 1                 music   Late Stage          ./BestPitchPDFs/spotify.pdf
# 2              proptech   Late Stage           ./BestPitchPDFs/wework.pdf
# 3          travelevents     Pre-Seed           ./BestPitchPDFs/airbnb.pdf
# 4           socialmedia  Early Stage         ./BestPitchPDFs/facebook.pdf
# ..                  ...          ...                                  ...
# 982  enterprisesoftware         Seed       ./InsiderPitchPDFs/Zestful.pdf
# 983             fintech      SeriesC          ./InsiderPitchPDFs/Zeta.pdf
# 984             fintech      SeriesA         ./InsiderPitchPDFs/Zevoy.pdf
# 985             fintech         Seed  ./InsiderPitchPDFs/ZoeFinancial.pdf
# 986              europe         Seed      ./InsiderPitchPDFs/7bridges.pdf
#
# [1799 rows x 3 columns]

# %%
twenty_sectors = ['Consumer', 'Cybersecurity', 'Data Analytics and Management', 'Education',
                  'Energy', 'Entertainment', 'Environment', 'Finance and Banking', 'Food',
                  'Health Care', 'Legal Tech', 'Marketing', 'Media and Advertising', 'Other',
                  'Real Estate', 'Tech', 'Transportation', 'Travel and Hospitality',
                  'Construction and Manufacturing', 'Enterprise']

def question_builder(industry):
    return "The twenty sectors to choose from are the following: " + \
           ', '.join([str(sector) for sector in twenty_sectors]) + ". \n" + \
           "Chose a single sector that maps best the sub-industry: " + industry + "? " + \
           "Reply with no explanation, just the name of the chosen sector."

# %%
import openai
def askGPT(text):
    openai.api_key = "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"
    
    response = openai.Completion.create(
        engine = "gpt-3.5-turbo",
        prompt = text,
        temperature = 0.6,
        max_tokens = 100
    )

    return response

# %%
import time

gpt_generated_industry_mapping = {'3dtechnology': 'Tech', 'abtesting': 'Marketing', 'accounting': 'Finance and Banking', 'adnetwork': 'Media and Advertising', 'adventuretravel': 'Travel and Hospitality', 'advertising': 'Media and Advertising', 'agriculture': 'Other', 'agtech': 'Agriculture', 'ai': 'Data Analytics and Management', 'airtransportation': 'Transportation', 'analytics': 'Data Analytics and Management', 'android': 'Tech', 'app': 'Tech', 'apps': 'Tech', 'art': 'Entertainment', 'assetmanagement': 'Finance and Banking', 'auctions': 'Finance and Banking', 'audio': 'Entertainment', 'augmentedreality': 'Entertainment', 'automotive': 'Transportation', 'b2b': 'Enterprise', 'banking': 'Finance and Banking', 'beauty': 'Consumer', 'bigdata': 'Data Analytics and Management', 'billing': 'Finance and Banking', 'bioinformatics': 'Health Care', 'biotechnology': 'Health Care', 'bitcoin': 'Cybersecurity', 'blockchain': 'Tech', 'brandmarketing': 'Marketing', 'broadcasting': 'Media and Advertising', 'buildingmaterial': 'Construction and Manufacturing', 'businessdevelopment': 'Enterprise', 'cad': 'Data Analytics and Management', 'cannabis': 'Other', 'careerplanning': 'Education', 'charity': 'Other', 'childeducation': 'Education', 'cleantech': 'Environment', 'clinicaltrials': 'Health Care', 'cloud': 'Tech', 'cloudcomputing': 'Tech', 'clouddataservices': 'Data Analytics and Management', 'coaching': 'Education', 'coding': 'Tech', 'coffee': 'Food', 'collaboration': 'Enterprise', 'collaborativeconsumption': 'Sharing Economy', 'commerciallending': 'Finance and Banking', 'computer': 'Tech', 'concerts': 'Entertainment', 'construction': 'Construction', 'consulting': 'Other', 'consumer': 'Consumer', 'consumerapp': 'Consumer', 'consumerelectronics': 'Consumer', 'consumergoods': 'Consumer', 'consumerlending': 'Finance and Banking', 'consumertech': 'Consumer', 'content': 'Media and Advertising', 'cooking': 'Food', 'corporatetraining': 'Education', 'coupons': 'Marketing', 'crm': 'Marketing', 'crowdfunding': 'Finance and Banking', 'crowdsourcing': 'Other', 'crypto': 'Cybersecurity', 'cryptocurrency': 'Finance and Banking', 'customerservice': 'Consumer', 'cybersecurity': 'Cybersecurity', 'database': 'Data Analytics and Management', 'datamanagement': 'Data Analytics and Management', 'datavisualization': 'Data Analytics and Management', 'dating': 'Entertainment', 'delivery': 'Transportation', 'developerapis': 'Tech', 'digitalentertainment': 'Entertainment', 'digitalmedia': 'Media and Advertising', 'digitalsignage': 'Entertainment', 'drone': 'Tech', 'ecommerce': 'Consumer', 'edtech': 'Education', 'education': 'Education', 'eldercare': 'Health Care', 'elderly': 'Health Care', 'elearning': 'Education', 'electronichealthrecord': 'Health Care', 'email': 'Data Analytics and Management', 'emailmarketing': 'Marketing', 'employment': 'Employment', 'energy': 'Energy', 'enterprise': 'Enterprise', 'enterprisear': 'Enterprise', 'enterprisesoftware': 'Enterprise', 'enterprisetech': 'Enterprise', 'entertainment': 'Entertainment', 'europe': 'Other', 'eventmanagement': 'Entertainment', 'events': 'Entertainment', 'fashion': 'Entertainment', 'finance': 'Finance and Banking', 'financialservices': 'Finance and Banking', 'fintech': 'Finance and Banking', 'fintechsecurity': 'Finance and Banking', 'fitness': 'Health Care', 'food': 'Food', 'foodandbeverage': 'Food', 'foodbeverages': 'Food', 'fooddelivery': 'Food', 'foodprocessing': 'Food', 'gaming': 'Entertainment', 'govtech': 'Other', 'guides': 'Education', 'hardware': 'Construction and Manufacturing', 'healthcare': 'Health Care', 'healthdiagnostics': 'Health Care', 'healthinsurance': 'Health Care', 'hospitality': 'Travel and Hospitality', 'hr': 'Human Resources', 'insurance': 'Finance and Banking', 'insurtech': 'Finance and Banking', 'intellectualproperty': 'Legal Tech', 'internet': 'Tech', 'iot': 'Tech', 'it': 'Real Estate', 'languagelearning': 'Education', 'legaltech': 'Legal Tech', 'locationbasedservices': 'Transportation', 'logistics': 'Transportation', 'machinelearning': 'Data Analytics and Management', 'manufacturing': 'Construction and Manufacturing', 'marketing': 'Marketing', 'marketplaces': 'Tech', 'media': 'Media and Advertising', 'mediaandentertainment': 'Media and Entertainment', 'messaging': 'Entertainment', 'mobileapps': 'Tech', 'mobilepayments': 'Finance and Banking', 'music': 'Entertainment', 'networking': 'Tech', 'onlinelearning': 'Education', 'opensource': 'Other', 'other': 'Other', 'payments': 'Finance and Banking', 'pitchdecktemplate': 'Marketing', 'productivity': 'Enterprise', 'proptech': 'Real Estate', 'realestate': 'Real Estate', 'recruiting': 'Legal Tech', 'restaurants': 'Food', 'retail': 'Consumer', 'ridesharing': 'Transportation', 'saas': 'Tech', 'searchengine': 'Tech', 'security': 'Cybersecurity', 'sensor': 'Tech', 'socialimpact': 'Other', 'socialmedia': 'Media and Advertising', 'software': 'Tech', 'sports': 'Entertainment', 'supplychainmanagement': 'Transportation', 'sustainability': ' Environment', 'tech': 'Tech', 'transportation': 'Transportation', 'travel': 'Travel and Hospitality', 'travelevents': 'Travel and Hospitality', 'venturecapital': 'Finance and Banking', 'video': 'Entertainment', 'virtualreality': 'Entertainment'}


## UNCOMMENT THIS WHEN ACTUALLY USING GPT TO REGENERATE MAPPING ##

# gpt_generated_industry_mapping = {}
# for industry in all_unique_industries:
#     question = question_builder(industry)
#     response = askGPT(question)
#     target_industry = response.choices[0].text.replace("\n", "")
#     gpt_generated_industry_mapping[industry] = target_industry
    
#     time.sleep(1)

# %%
# print(gpt_generated_industry_mapping)

# %%
master_df["Industry"] = master_df["Industry"].apply(lambda x : gpt_generated_industry_mapping[x])
broken_pdfs = []

# %%
import pytesseract
from PIL import Image
import io
import pdfplumber
from pathlib import Path
from wand.exceptions import WandError

# %%
def extract_txt_files(pdf_link):
    try:
        company_name = pdf_link.split("/")[-1][:-4]
        print(company_name)

        text_file_path = "./ExtractionsInTXT/" + company_name + ".txt"
        if (Path(text_file_path).is_file()):
            return

        with pdfplumber.open(pdf_link) as pdf:
            full_text = ""
            for page in pdf.pages:
                image = page.to_image().original
                page_text = pytesseract.image_to_string(image)
                full_text += page_text

            with open(text_file_path, "w") as text_file:
                text_file.write(full_text)
    
    except WandError:
        broken_pdfs.append(text_file_path)
        print(f"Error: Unable to extract text from {pdf_link}")

# %%
## UNCOMMENT THIS IF YOU WANT TO RERUN TEXT EXTRACTION
# master_df["PDF URL"].apply(extract_txt_files)

# %%
display(master_df)
# Out:
#                    Industry        Stage                              PDF URL
# 0                      Tech     Series D             ./BestPitchPDFs/bolt.pdf
# 1             Entertainment   Late Stage          ./BestPitchPDFs/spotify.pdf
# 2               Real Estate   Late Stage           ./BestPitchPDFs/wework.pdf
# 3    Travel and Hospitality     Pre-Seed           ./BestPitchPDFs/airbnb.pdf
# 4     Media and Advertising  Early Stage         ./BestPitchPDFs/facebook.pdf
# ..                      ...          ...                                  ...
# 982              Enterprise         Seed       ./InsiderPitchPDFs/Zestful.pdf
# 983     Finance and Banking      SeriesC          ./InsiderPitchPDFs/Zeta.pdf
# 984     Finance and Banking      SeriesA         ./InsiderPitchPDFs/Zevoy.pdf
# 985     Finance and Banking         Seed  ./InsiderPitchPDFs/ZoeFinancial.pdf
# 986                   Other         Seed      ./InsiderPitchPDFs/7bridges.pdf
#
# [1799 rows x 3 columns]

# %%
import re
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.corpus import words
from nltk.tokenize import word_tokenize

Lem = WordNetLemmatizer()
stop_words = stopwords.words("english")
english_words = set(words.words())
unigram_freq_df = pd.read_csv("unigram_freq.csv")
unigram_freq_dict = pd.Series(unigram_freq_df["count"].values, index = unigram_freq_df["word"]).to_dict()
frequency_threshold = 5 * 10e6

def preprocessing_lambda(text):
    # Make everything lowercase.
    out_text = str(text).lower()
    # Remove mentions, hashtags and urls.
    out_text = re.sub(r"(?:\@|\#|https?\://)\S+", "", out_text)
    # Keep alphabetic sequences only
    out_text = re.sub(r'[^a-zA-Z]', ' ', out_text)
    
    # tokenize sentence
    token_out = word_tokenize(out_text)
    
    
    # Lemmatize words using both settings from nltk as:
    # 'v' works for bombing -> bomb
    # 'n' works for years-> year
    out_text = " ".join([Lem.lemmatize(Lem.lemmatize(w, 'v'), 'n') for w in token_out])

    # Keep only words longer than two characters
    # ignore stopwords and words that are not in the english vocabulary
    token_out = [w for w in token_out if (not w in stop_words) and (w in english_words) and 
                 ((w in unigram_freq_dict) and unigram_freq_dict[w] > frequency_threshold) \
                 and (len(w) > 2)]
    
    
    
    return " ".join([w for w in token_out])

# %%
def write_processed_text_to_csv(pdf_link):
    company_name = pdf_link.split("/")[-1][:-4]
    print(em_s + company_name.upper() + em_e)

    text_file_path = "./ExtractionsInTXT/" + company_name + ".txt"
    if not(Path(text_file_path).is_file()):
        return None
    
    with open(text_file_path) as txt_file:
        raw_text = txt_file.read()
        processed_text = preprocessing_lambda(raw_text)
        print(processed_text, "\n")
        time.sleep(0.01)
        return processed_text

# %%
master_df["Processed Text"] = master_df["PDF URL"].apply(write_processed_text_to_csv)
# Out:
# BOLT
# global network around powered one account single site see one login one click player wide core impact network sea network hit culture one account
#
# SPOTIFY
# computer science language idea like running water million active within previous days million come fast always working much possible fast fast always working nothing build talk error test code fire cut cable long distance getting right tool job availability availability user search memory daily read search sort search index memory storage storage long storage storage better use memory storage high choose level source master yes please come work well
#
# WEWORK
# space service community people new work fee powered technology every first value value added capital deal opportunity membership mobile experience growth mobile social provide strong interest member base physical making city opportunity
#
# AIRBNB
# welcome book rather problem price important travel leave city culture easy way book local become solution rent space market market size budget product business model take commission fee strategy money design brand browse user interface business development brand design press user financial looking round
#
# FACEBOOK
# see directory user basis social school system last user access lot school global function user add university college seen year food college site site user growth rate growth rate number marketing basis rent contact
#
# YUGALABS
# disclaimer company future company web company big space forward building next club club know success must learn work together active community space community days building date day far million volume account volume sell center new one club real every member access want build something also net community future race art question moving matter care land lot face virtual social enough hold today trying make something new really something whole point else everyone building work later thing already people ass building building build come meet story brand current culture pop culture fun right building see create something brand new experience money real actually land everyone bring character anyone build build game total annual community best already living web game whole new one power store like also allow race game land sale real land game see unique want look feel net thank
#
# COPYAI
# copy may problem hard create content need business time much time write content need hard get limited think new say solution powered marketing content need business copy early run rate copy need create content order use product social media copy top marketing create graphics update social media run copy copy user interface easy use product click button create copy get copy copy value copy
#
# OSHIHEALTH
# access health health top cost category population condition health given cost current care testing treatment provide get current care current average visit room average annual care virtual first whole person care team plan member people condition health care study national health plan gold standard study design national health plan population forum abstract journal march institute control usually member experience work days quality life well health significant year one per year one medical cost related full year care less one visit based health access care insurance people access cover leading local currently browse population join mission free people build market health company feed
#
# QUANTEXA
# overview global decision address large see single data business different open secure see series investment strategy thank feed
#
# CAREERIST
# finance place job tech san tech job finance place job tech problem job market job enough solution room already job get business model risk payment network effect section high client rating market change change tech team product lead growth thank
#
# VUESTOREFRONT
# already trust building problem problem solution age unique approach already done past later create new category service way people buy going forward starting market fast long run even today potential future enterprise content management global travel market insurance market deep company building experience best class team
#
# SOLOFUNDS
# cover funds mobile exchange purpose providing access score potential solution filter live feed money live feed works sign financial financial product market new press ever new market right message thank red
#
# BARNETTX
# girl business yahoo
#
# NOCD
# community end drive cost due rent market personal experience effective treatment come strong economic help people community growth search ring additional growth word training
#
# OURFUTURE
# get per
#
# MACRO
# fast new important external communication current office create information really change anything could old chat like everything browse best
#
# INFLUXDATA
# times series data picture true category large customer base time series category document search time series see following well data best time building two physical mission use cover recent time series category score category lot market data market data year growth rate data industry together opportunity time series one common across open source case performance time series engine data community open source high performance time series per second
#
# SUPERNORMAL
# meeting system record per product band early
#
#
# fund next favorite thing one done better performance fund fund june fund product late come week create people must product tech new want term want net score investment focus fund consumer technology went remote work love making one easy key work coming fund new working even fund structure size stage investment back legal disclaimer thanks meet cross son meet company meet cross meet writing lot someone write work every new status market stage stage white fund late focus big based data size times stage son minimum check lower plan given often send every two process new print capital show end structure year yes
#
# HELLOBELLO
# company easy provide food market age want live longer life food needs maximum target series operation state team none place shall business position dog food player german market today average dog buy end dog food leading cancer even dog need dog problem shipping dog click button right door strong data love problem customer feedback rating based region defined higher pay port key consumer last age significant seen dog german market end sat san even potential market well thanks high degree product quality different focus high degree individual high quality dog food tech first approach high product one stop shop well wide range experience growth best less food return shipping sat
#
# NGROK
# morning build world class team sea core web useful without access see get one line system one line getting lot work production one line one line
#
# PEARPOP
# new growth marketing use marketing time marketing could tech new standard marketing world best trust getting community community continue data support powered web data power team thank feed
#
# FTX
# sea overview change change exchange exchange statistics come core room current product new new real new product win team effective given contact
#
# DANDELIONENERGY
# world moving work first product low cost home full technology approach easy purchase purchase clear win brand building brand market building allow every home hardware financial channel
#
# LEGIONM
# let put first entertainment company buy world first entertainment company million core growth hit good fun good business business model face business model growth power anything business needs right future industry idea company think idea good wish thought
#
# TVISION
# consumer average time media industry new approach approach single panel second today panel data limited future big data panel data panel key business
#
# ALATION
# business overview august right time system date data data supply data human making data right need data within market also data active management set everything data data everyone net people love working best
#
# CANARYTECHNOLOGIES
# deep domain problem many technology solution tech soon digital guest guest market digital staff guest modern prior found first solution digital best digital solution digital designed hotel need see digital first mobile web end end guest management system industry leading help drive staff provide best guest experience set major global brand trust improve guest experience east use property management system made check technology useful business hotel drive story far growth comes next market size open today direct care
#
# KYRA
# home track record works building home video technology one business mode built
#
# HUMMINGHOMES
# making home home management modern early first time home home make every home home solution life category home management entire value true value membership home management service customer distribution strategy consumer marketing market network become consumer home market distribution home management every home management
#
#
# fund next favorite thing one done better performance fund fund june fund product late come week create people must product tech new want term want net score investment focus fund consumer technology went remote work love making one easy key work coming fund new working even fund structure size stage investment back legal disclaimer thanks meet cross son meet company meet cross meet writing lot someone write work every new status market stage stage white fund late focus big based data size times stage son minimum check lower plan given often send every two process new print capital show end structure year yes
#
# FOLXHEALTH
# population large rate power power report prior form people face health care needs community health leading health care providing end end across community needs every body core care network care training education content community community built strong brand time press position category virtual network average training quality aid drive built following health content community give access group based care health learning community based content specific needs community deep enterprise drive growth part increase want many know start community
#
# SUPLIFUL
# brand long hard support team never super easy pay need content works main feedback high store pass similar simply private brand package already use print content without external early investment sale private social multiple pro like learn different core add different product looking market growth manager
#
# CALAXY
# works core market million business model team team stock project director team
#
# VORI
# solution local regional active growth deep understand market independent independent market category still run paper run cost everything supply cost meet one back office order management management retail earth global total team born
#
# HUMAANS
# see see basis
#
# X1
# around credit card consumer credit card credit card consumer card card purchase volume product finance product use social drive network effects growth word media unique marketing browse best world library
#
# MUCKRACK
# public company overview management easy use yet part opportunity within public marketing core media success public brand ever sea media media media become leading marketing strategy content important user content digital media seen least content management category data feedback people media across digital print social send team activity working one never across ever media success value free content best work solution one success send major industry public without low quality data media category industry first professional network east multiple growth include additional market share new like time money trying develop used time card map ever media without road browse best world library
#
# HADEAN
# built case net global peter global per virtual conference enter net art net sea east see
#
# MODERNPICNIC
# modern modern first market currently modern female version since function customer current age distribution total unique date press health today yahoo brand program brand distribution strategy key data customer modern start outside growth date pack
#
# FORTANIX
# security data technology data secure meet security even use data security data growth data privacy increase data volume enterprise data data public risk data privacy annual per source protection work data first security first security focus security data first security secure data male data selected control data across data security manager global service multiple allow data control key partner lake program sale ready availability commercial government availability lead partner control new data security lead partner service partner availability strong year growth growth strong almost product global across federal strong property base significant use recently solution web use strong team recent legal
#
# ROKOKO
# problem solution one stop shop digital digital per one commercial see around engine see new starting health board move world play history
#
# PARTYROUND
# party round party round easy money people create around many people safe law way social need better access mobile first experience whole network whole world wish every welcome party
#
# EVERSIDEHEALTH
# introduction health health technology primary care health total cost care current state system source see plan significant cost plan value based care help plan shown win business model provide one solution person virtual total cost care look line local plan last national care mission management team track record success key make unique
#
# RING
# last million run rate first round soon funds far hardware mature industry hardware good phone could better see review apple gold wireless phone another phone yes another people require higher standard technology create better version previous version product great device new hardware new phone next camera model product include screen team complete solution full customer experience business apple level quality success design video customer service mission brand focus clear long term mission active field long term approach year apple big team team
#
# VIDMOB
# key marketing performance see see everyone looking learning run need digital increase ways work data next drive impact business upon performance time major mac date kind mission see global across million entire modern work around world say see big core video view data digital marketing act whole process
#
# THERIGHTSTUFF
# dating right age idea good person far effective mar find someone date large people looking true looking key dating different kind dating right date real real browse best world library
#
# MITERRO
# engineering end cover problem first solution solution market size market protein product side product material product market case study team road map second product road map used amount application environmental release defined market size total available market global single use available mark global total market share annual growth past product film single use film total every water use browse best world library leading every week need
#
# VERISHOP
# ability make world better shopping experience digital independent brand community independent help new market greater ever retail source want better brand like try new love try new try new never try new end global problem independent lost need place tell story business partner help marketing operating know new people come across new social feed however shopping experience social easy way search sort often delivery customer service area data sell partner business brand profile tell brand story better knowledge management interface help share knowledge data improve image management cost management cash lower say independent call home problem content feed let browse find take two site customer engine computer learning based new tell shopping tell friendly forum chat purchase two technology create product video unique content library across world access browse shopping never always customer experience first click full customer support first many take across world technology problem live shopping party engine custom new brand tech content distribution product video real time net score business light model strong content browse best world library
#
# AISERA
# service overview marketing finance legal customer service support customer experience best class customer organization top mind experience peter force digital experience experience see way forward business key address across organization business enterprise wide current state hard find high high support information service experience case study study case study case study case study power search service experience user cool research see browse best world library
#
# OSSOVR
# higher level improve increase access million million smith university work training improve work standard training education digital education strategy one
#
# SUPERBYMETA
# super super run public new meet create digital version person meet number would like learn best media within super show super provide show content provide provide necessary graphics media content keep super provide post show report information please contact super super super content super meet support favorite late night talk feature live super web require watch free mobile well support digital previous super please visit one super believe menu different right experience current focus better understand best experience super certain find financial strategy life full responsibility background content show links interest post event available payment super additional show media event technical support event survey super show experience super show show min prior start show link background watch video event start event second video auto single life full meet meet link background super receive take away social media background post event link video opportunity show links able limited amount post show regarding product early build one additional event event page event watch time additional super super play together answer first talk team first win event provide direct links store well note product yet would require additional development work opportunity super event delivery thanks information please contact super
#
# KANGAROOTIME
# management market overview enter center center staff management point care management user experience easy experience payment experience experience experience end record digital track vacation director experience enterprise unit best class customer support phone support user director program war love program easy help may child care center care pay place use funds new add end improve share continue key
#
# MINUT
# home community lot say growth
#
# TOMORROWHEALTH
# home primary place care solution team world class industry board care home rate today process everyone solution better care super care ability care material value like health plan partner access care care home thank
#
# RIAHEALTH
# mission team group national next health economic hospital disease since june study eye get care create financial much time family community health treatment member health treatment system quality risk risk days risk one year health care one level risk two level risk lower core lower health care health payment model treatment health state team team thank treatment
#
# FRONT
# front impact front work best work business huge corporate business standard per day year also ever user work problem outside making tool still get stock front model become many information access speed hard keep team best front team job along market front front done strong growth yet growth user join date art ass current net approach growth use front approach growth know find tell head client head customer success director corporate travel agency approach growth knowledge build new business post market strong business strong use marketing make needs live communication done space great product share per type current get enough front min user day yet keep always trying find ways bring one place great thing build one different stay front business front like place people enjoy living home screen mean business lot different information front information place everyone given problem customer end game building already today directly front front thank
#
# GRUBBRR
# core seen movie solution product value improve customer experience order custom market market direct best partner marketing payment single act peter social media partner management one support success delivery global application men development security model
#
# PARTYROUND
# party round party round easy money people create around many people safe law way social need better access mobile first experience whole network whole world wish every welcome party
#
# PRODUCTSUP
# next market major new product consumer category order market loss look like product value take management ground deal art operating market solution level much information multiple entry customer use product consumer opportunity statement purpose statement mission percent
#
# TBD
# web web message per
#
# BRANCH
# built win unique distribution low high customer insurance market one last large home auto insurance company designed insurance less price point built problem one name built win solution fee built value insurance rate account percent
#
# UPFLEX
# office way world works net pay market opportunity office real estate office different network one one one bill took use management team thank
#
# FIREWORK
# next consumer short video china leading way short form video short video short video end end solution create easy create short live end product sat significant across world live seen growth previous deep retail industry mark
#
# KRYPTOMON
# play seen game game game use funds analysis marketing strategy high level
#
# HOWGOOD
# impact analysis
#
# BELGIANBOYS
# industry growth customer experience start day needs channel brand teen sea
#
# MATHISON
# product market large fast market ready week history top important full team problem end end net single point none anal solution future space system code tech end global market large market come deep domain wrote best book ring tech along track record provide system system strategy war provide ring process state fee copy strategy significant cost food company company team series next growth name data science german code win world war later gay middle name fast sell art period major target focus thank percent
#
# SOLCHICKS
# example success since ago success low entertainment quality user entertainment model built following people game become leading given regarding network error per still per one car team across key schedule
#
# MODULR
# say even pressure payment forward modern direct open come better payment example high volume enterprise customer market approach win enterprise fast opportunity strong percent
#
# AIRUDDER
# company red see high communication customer year customer experience business model series thank
#
# BLUEOCEAN
# series overview brand brand commercial strategy organization something big brand entry point many mar first brand research strategy sure brand old meet brand brand make brand everyone business today
#
# PADDLE
# net new net starting starting net new delivery third growth today delivery delivery back delivery enter turn new business become one click growth ready delivery delivery remove delivery month enterprise delivery delivery growth ready future
#
# HELLOHEART
# heart overview digital solution heart health heart disease cause death world built digital solution people track heart self happy market heart heart soon make one heart digital health level something seen management pressure could person heart death institute heart cost change per heart annual team market got
#
# OURSONG
# value everyone making market net market high price could first went sale top bid market value population non mobile first experience local language song non without community fee use case world first international music japan global star set net new net happy company team
#
# JUNO
# way experience work since day one create category way work become company experience pressure may require provide solution tool war global war working health tool primary player global better best class best global everyone needs unique end game product team built technology case experience one physical
#
# THUNKABLE
# mobile development important building mobile today really hard simple car save development across growth almost common non marketing fall record working together code
#
# STARBURST
# data house house data want big made many big date market making move data one place better data data move data one place much data model may access data matter stay want free
#
# NORDSECURITY
# mission security privacy two leading protection culture success industry leading network age far network security age global date customer experience brand customer experience band drive growth consumer brand marketing engine channel cost rated media guide create media top mission global access
#
# SANOGENETICS
# management medicine research track non next medicine opportunity built per per day huge cost cost plus add medicine access people medical data significant several every population people network medicine research disease long would three key market use match life medicine research use user experience use find right let team meet meet
#
# ARKKAPITAL
# believe make word better better art high risk finance company three different one similar drive build actually work land tech finance see tech next tech real time rate financial cart business performance time first two product cover term growth term forward fee boy power world tech
#
# SECUREFRAME
# series higher security rate getting today team lost evidence support process believe simple organization follow security without security purpose built security evidence collection data approach love security market thank
#
# AMAGI
# help live value full value mon help three core access fast network world new turn live sports best yahoo service age support new bad mac pay
#
# BUBBLE
# taking development code development going change code limited make build anyone build product opportunity build reference code take development engineering market opportunity trying instead focus limited use people build custom without code full product use use learn within days growth last yet non technical business need product never customer san rate get million process business volume community product love product since active social community see per month hard potential long term need production ready general purpose tool make better first company market use tool buy unique term code four growth many business already clear recent ass tech improve high end learning past would growth growth education name brand position reference major media education inside march mission team lead turn name take development lead reference thank
#
# YUGALABS
# disclaimer company future company web company big space forward building next club club know success must learn work together active community space community days building date day far million volume account volume sell center new one club real every member access want build something also net community future race art question moving matter care land lot face virtual social enough hold today trying make something new really something whole point else everyone building work later thing already people ass building building build come meet story brand current culture pop culture fun right building see create something brand new experience money real actually land everyone bring character anyone build build game total annual community best already living web game whole new one power store like also allow race game land sale real land game see unique want look feel net thank
#
# ALMOSTFRIDAY
# culture
#
# CLAAP
# meeting seen men product business model main focus already team peter area tue
#
# CHARTMETRIC
# executive report table contents business model music industry introduction data offer everyone music industry short release solution rent thus property whole analysis product data overview free artist new single pay global marketing impact solution case art team art market size global music growth overall market size market key customer people market global market size size market marketing live teen risk data win business model growth business model current key date target market potential user share growth annual additional growth additional growth artist page cross performance artist list custom get
#
# THREESHIPS
# natural brand market works best growth use funds look
#
#
# fund next favorite thing one done better performance fund fund june fund product late come week create people must product tech new want term want net score investment focus fund consumer technology went remote work love making one easy key work coming fund new working even fund structure size stage investment back legal disclaimer thanks meet cross son meet company meet cross meet writing lot someone write work every new status market stage stage white fund late focus big based data size times stage son minimum check lower plan given often send every two process new print capital show end structure year yes
#
#
# fund next favorite thing one done better performance fund fund june fund product late come week create people must product tech new want term want net score investment focus fund consumer technology went remote work love making one easy key work coming fund new working even fund structure size stage investment back legal disclaimer thanks meet cross son meet company meet cross meet writing lot someone write work every new status market stage stage white fund late focus big based data size times stage son minimum check lower plan given often send every two process new print capital show end structure year yes
#
#
# fund next favorite thing one done better performance fund fund june fund product late come week create people must product tech new want term want net score investment focus fund consumer technology went remote work love making one easy key work coming fund new working even fund structure size stage investment back legal disclaimer thanks meet cross son meet company meet cross meet writing lot someone write work every new status market stage stage white fund late focus big based data size times stage son minimum check lower plan given often send every two process new print capital show end structure year yes
#
#
# fund next favorite thing one done better performance fund fund june fund product late come week create people must product tech new want term want net score investment focus fund consumer technology went remote work love making one easy key work coming fund new working even fund structure size stage investment back legal disclaimer thanks meet cross son meet company meet cross meet writing lot someone write work every new status market stage stage white fund late focus big based data size times stage son minimum check lower plan given often send every two process new print capital show end structure year yes
#
#
# fund next favorite thing one done better performance fund fund june fund product late come week create people must product tech new want term want net score investment focus fund consumer technology went remote work love making one easy key work coming fund new working even fund structure size stage investment back legal disclaimer thanks meet cross son meet company meet cross meet writing lot someone write work every new status market stage stage white fund late focus big based data size times stage son minimum check lower plan given often send every two process new print capital show end structure year yes
#
#
# fund next favorite thing one done better performance fund fund june fund product late come week create people must product tech new want term want net score investment focus fund consumer technology went remote work love making one easy key work coming fund new working even fund structure size stage investment back legal disclaimer thanks meet cross son meet company meet cross meet writing lot someone write work every new status market stage stage white fund late focus big based data size times stage son minimum check lower plan given often send every two process new print capital show end structure year yes
#
#
# fund next favorite thing one done better performance fund fund june fund product late come week create people must product tech new want term want net score investment focus fund consumer technology went remote work love making one easy key work coming fund new working even fund structure size stage investment back legal disclaimer thanks meet cross son meet company meet cross meet writing lot someone write work every new status market stage stage white fund late focus big based data size times stage son minimum check lower plan given often send every two process new print capital show end structure year yes
#
#
# fund next favorite thing one done better performance fund fund june fund product late come week create people must product tech new want term want net score investment focus fund consumer technology went remote work love making one easy key work coming fund new working even fund structure size stage investment back legal disclaimer thanks meet cross son meet company meet cross meet writing lot someone write work every new status market stage stage white fund late focus big based data size times stage son minimum check lower plan given often send every two process new print capital show end structure year yes
#
#
# fund next favorite thing one done better performance fund fund june fund product late come week create people must product tech new want term want net score investment focus fund consumer technology went remote work love making one easy key work coming fund new working even fund structure size stage investment back legal disclaimer thanks meet cross son meet company meet cross meet writing lot someone write work every new status market stage stage white fund late focus big based data size times stage son minimum check lower plan given often send every two process new print capital show end structure year yes
#
#
# fund next favorite thing one done better performance fund fund june fund product late come week create people must product tech new want term want net score investment focus fund consumer technology went remote work love making one easy key work coming fund new working even fund structure size stage investment back legal disclaimer thanks meet cross son meet company meet cross meet writing lot someone write work every new status market stage stage white fund late focus big based data size times stage son minimum check lower plan given often send every two process new print capital show end structure year yes
#
#
# fund next favorite thing one done better performance fund fund june fund product late come week create people must product tech new want term want net score investment focus fund consumer technology went remote work love making one easy key work coming fund new working even fund structure size stage investment back legal disclaimer thanks meet cross son meet company meet cross meet writing lot someone write work every new status market stage stage white fund late focus big based data size times stage son minimum check lower plan given often send every two process new print capital show end structure year yes
#
#
# fund next favorite thing one done better performance fund fund june fund product late come week create people must product tech new want term want net score investment focus fund consumer technology went remote work love making one easy key work coming fund new working even fund structure size stage investment back legal disclaimer thanks meet cross son meet company meet cross meet writing lot someone write work every new status market stage stage white fund late focus big based data size times stage son minimum check lower plan given often send every two process new print capital show end structure year yes
#
#
# fund next favorite thing one done better performance fund fund june fund product late come week create people must product tech new want term want net score investment focus fund consumer technology went remote work love making one easy key work coming fund new working even fund structure size stage investment back legal disclaimer thanks meet cross son meet company meet cross meet writing lot someone write work every new status market stage stage white fund late focus big based data size times stage son minimum check lower plan given often send every two process new print capital show end structure year yes
#
# PLAYSTUDIOS
# fee bay put bar tue basic
#
# TIA
# system left virtual care longer hospital become customer system future care delivery care delivery health category customer care delivery turn far trust person practice health care shop get stay well every player brand care tech tech brand experience company tell anyone industry love whole woman whole life care model real woman life throughout life new standard far customer get much virtual limited offer virtual person thing line tech care via three tech car care management everyone across decision support whole person model quality control level like care team higher quality care lower clear primary care lower cost per service value far front door across make door total mind annual system power partner health true growth less capital health give better access insurance care financial support today team come consumer world brand user design date create new believe working system team build company
#
# 100PLUS
# plus plus leading remote company overview leading remote business model growth capital staff risk technology practice training device distribution access via team practice based performance mar may net since additional added mar may plus plus history limited financial making less care ever going office significant risk heart disease care see less average year social security transportation care result result care primary care result condition use room care average visit plus plus remote remote new program care cost since every practice result become mission works medical track review data month ensure risk event plus per per year plus provide service average primary care plus data review per per year remote additional average primary care never program large change plus plus average primary care remote potential additional plus education review basic first min add based need review basic add min pay plus service fee medical one time support multiple per included total per month add code additional zip code plus plus plus product business model risk way remote start days solution capital free running effective data health plus need business school digital plus plus plus training directly risk within practice data partner data plus medical prior check ensure device shipping directly ready use box without need phone upon device delivery training plus program ready use information ship medical plus population health management plus population health population health management association heart association outside safe range staff ensure condition population health management plus also able one plus data review data plus device practice review data meet review see still month plus review best practice plus plus track submit time review know review ensure month account payment error business day time providing getting plus practice extra work practice submit coming plus plus plus full cost risk end end solution plus health white education ability entire days population health management high risk free user ready use free without plan bill data without user provided available additional cost medical practice link device number profile must use device manufacturer set plus plus plus full cost risk end end solution plus health white education ability entire days population health management high risk free user ready use free without plan bill data without user provided available additional cost medical practice link device number profile must use device manufacturer set plus plus team plus team remote deep domain experience technology executive practice director grand central finance practice senior head product product manager senior manager product head senior business manager development manager head content marketing director marketing content marketing manager head account management director customer service director technical support practice plus general senior silver lake president black rock technical engineering case head business development senior national head design senior june product design head customer success product manager customer success practice plus world author life play code partner two code show president capital plus plus blood pressure plus blood pressure reading advanced blood pressure sent available better care device data practice user ready use box high blood pressure heart disease heart plus blood plus blood plus blood get information make better based level data test control solution result within information directly review analysis time see take action need type plus digital weight digital weight keep track weight plus digital weight providing heart weight related health like clear data ready use box weight loss plus plus non contact distance cross multiple people result one second designed provide quick way blood rate sports use plus plus plus
#
# ALLOY
# problem million getting looking find right post health study treatment study health large market range alternative medicine use problem community ready talk first life baby center came time help age feel like value community age health partner hot value community age take select medical assessment receive door community access science based plant based low work treatment effective solution community regular partner brand market solution ship additional market health needs board part family focus start year win coming thank
#
# SQUIRE
# business management need one solution specific needs first one stop shop men payment without payment management system consumer white team last new new june growth response gift could feature virtual room feature time net shop growth new new large enough drive market small offer end end system unique industry core shop owner
#
# NANONETS
# world document communication making across still paper record problem current document based solution united deep learning mode overall market industry growth end end format machine learning works time live works business model page five trial growth team building machine learning together thank
#
# SCIPHERMEDICINE
# unique disease test test opportunity first anti blood test non response anti show cost fee test rate see data lake every day
#
# BACKBONE
# marketing production budget thank
#
# TELADOC
# primary experience love see seen data care person primary whole person care experience care develop member care team mode care core support change support long united core team chat care team navigation quality cost effective care art future last meet late member impact market impact
#
# VANGST
# hard industry job van easy technology industry growth getting opportunity new team made industry take unique opportunity
#
# STARBURST
# data house house data want big made many big date market making move data one place better data data move data one place much data model may access data matter stay want free
#
# CROWDBOTICS
# new way application development see wed
#
# CHARTMETRIC
# executive report table contents business model music industry introduction data offer everyone music industry short release solution rent thus property whole analysis product data overview free artist new single pay global marketing impact solution case art team art market size global music growth overall market size market key customer people market global market size size market marketing live teen risk data win business model growth business model current key date target market potential user share growth annual additional growth additional growth artist page cross performance artist list custom get
#
# AUTHORITIVE
# build learning live opportunity connection solution learning individual learning thank
#
# RIPPLING
# introduction job rent new product overview end performance date average small size network effects
#
# NOW
# mission help payment small middle market need capital often fact get unique structure get without time providing capital structure better safety fund business get way like credit card payment needs use late risk management cost without way credit sell trade credit business government account create world access capital customer seen see quality fact son use end machine west volume move team
#
# LADDER
# building next life insurance company new one life digital leading life product long front end customer experience simple beautiful score power insurance love stay data time machine data growth
#
# ORIGYNFOUNDATION
# human experience believe ensure role digital age trust modern access create share without write digital use strong industrial grade device leading network computer advanced make non digital teen mission statement financial security also leading advanced environment make home leading global like united structure mission built top late original customer art art market connection physical art digital digital media run world feel keep digital property safe team business head research general technology brand within industry experience organization council member foundation model wall teen since board valley association partner working global financial
#
# BOLT
# global network around powered one account single site see one login one click player wide core impact network sea network hit culture one account
#
# SOLCHICKS
# example success since ago success low entertainment quality user entertainment model built following people game become leading given regarding network error per still per one car team across key schedule
#
# COPYAI
# copy may problem hard create content need business time much time write content need hard get limited think new say solution powered marketing content need business copy early run rate copy need create content order use product social media copy top marketing create graphics update social media run copy copy user interface easy use product click button create copy get copy copy value copy
#
# PERSEFONI
# environmental financial see set
#
# FACEBOOK
# see directory user basis social school system last user access lot school global function user add university college seen year food college site site user growth rate growth rate number marketing basis rent contact
#
# FYREFESTIVAL
# network take commission series water press brand team experience music entertainment industry
#
# TALKABLE
# marketing live way eye give impact performance status eye
#
# UBER
# ...
#
# AFROCENCHIX
# name hair customer june black race yet black feel high street meet health beauty needs report reserved enter brand free core currently become one stop shop hair travel full full key make natural simple safe effective content run rate strong due house product development across supply growth rate hair brand whole summer retail available independent health food traffic last traffic page hair care reserved line rate based real customer top last increase size past first well industry standard return huge increase previous return time every reserved special consumer beauty natural core foundation community trust health brand category supply trade science data community data used create new effective talk daily understand data word growth average customer rating reserved house real hair unique approach release new project year fast industry standard love work feel thank product use ago say life son full range love happy hair happy take time product find right way keep natural hair always really day know hair found must hair getting car second come many much recently found say gay happy used back works used first time today away hair never thanks much though life thank idea much life ability natural hair also shown show best people well reserved reason love give amount people know time money help hair find one best family use know read different ways way thanks much hair plus actually keep simple also love huge fast market opportunity people hair baby world black brown black race hair main hair type beauty world growth product global product market size reserved opportunity safe natural safe natural form nature reserved growth product investment store received reserved natural simple team key new content customer experience product equipment speed sell house reserved marketing content digital making natural simple chat since may first new product body care global west reserved press menu independent best way ensure hair apply oil process based natural hair meet woman posted life hair instead due natural oil oil oil oil buy black award reserved content social media team market marketing director supply manager content full reserved director finance retail digital lead production global black market ready change limited retail growth next lead market consumer fast direct customer data huge growth increase low marketing black matter seen support black black day one day little additional marketing hair stay growth june next best choice global black market making natural simple help lead market safe effective contact unit house road
#
# AGAVEGAMES
# team building trust data strategy san strategy strategy industrial engineering research degree studio lead good job growth manager good job responsible marketing product manager good job studio head growth good job head growth directly level design game feature long large strategy long term company multiple long different user experience target needs target want make game even greater level design level design data level system built needs top live live work take one step marketing marketing cost making sure right advertising low high purchase see huge growth opportunity game area advertising model purchase team built great team share senior technical senior game game data game artist game artist artist come year data game development game experience artist experience science experience experience art various game server lead technical well experience development service capital capital plan first game ready test game time start building second studio thank
#
# AGBIOME
# water company multiple research experience business development research commercial director board year finance professional business bill foundation company overview protection global food production process feed world real world best class collection commercial protection consumer safe food advanced safety people large environment impact company red core industry leading first company world every development result active commercial collection fee data science every per second leading across range market san process son designed house protection today working life good need protection new study united population feed account use land union china according study united used one use country according study less market also used china food long term growth seen stop huge opportunity protection third market market market market market share industry global market share group first application effective protection control non field plant product year year post product global market value sort post address unique significant business development human health animal health outside core business animal health early license control active animal feed industrial early license early license human health animal health multiple early license natural product drug early license multiple business product development four business multiple business value model development enterprise value market access license enterprise value early cash early market access late global development development health key investment global problem food known real need increase food production address needs science technology technology science technology advanced time market industry leading protection additional market market opportunity protection additional market create potential become world leading company strong ensure success provide external industry leading across ability non cash long term product blue channel across commercial distribution product research development market huge financial opportunity significant first full year product product support across multiple key value deep product top management team purpose team industry experience leading technology many industry leading future production food
#
# AGERASGROUP
# meet business get done like bank loan project went build business around lot made early learning important focus product technology team set found group strong success small professional young team lead one insurance building first business full today since organization performance growth clear first project age building since within media everything public strategy marketing wrote first line code used marketing lead special within group success mission building best around needs target become ever total market growth engine new new business together result customer customer use group total market cross customer result cross sell customer customer customer use result customer product review leading business quote final price message free easy provide choose win business need increase budget right match find good industry cheap marketing offer higher detailed get profile product review one leading based show tax product review quality ready address future time management management financial service value cost business regular short term business personal customer cost since finance customer providing financial top service risk associated finance partner bank take risk sent customer finance take risk customer risk free finance customer limited cost risk financial group service live financial data make easy credit financial financial future future financial financial open data credit management resource corporate financial financial decision making data analysis deal value deal selected may private may private strong way future growth new strong market position growth engine mean digital business model growth growth growth huge number market size annual market every year finance administration total number per total market per less total number average per business small internal legal medium source small business administration office score group financial service customer focus comes management one stop business one stop solution one stop solution big tech line line one stop low group high comment group player line group become one stop solution find business needs single core service moving line one stop additional coming moving customer model line one service
#
# YUMINUTRITION
# believe everyone able taking everyone take form providing best quality industry brand ready problem bad range within market market solution range good market strong brand try wish good hair skin future apple customer much better hair feel much skin morning well sure market market market research growth market market research format market size current market taken form past year take take every day week market every additional account application market market low product low price high product high price marketing social media growth especially market health team business marketing experience business previous role year degree business finance financial technology record business previous role month start model degree design young enterprise per cost per shipping cost per new customer per business already needs cash new month target strong management team experience marketing new business point financial already looking cash new back business include added cost net future market view across new introduction new within next potential brand different product staff marketing growth new marketing budget budget new increase increase product line staff bring marketing get
#
# ZESTFUL
# membership card real time track real time process card card core payment technology never good custom card real time product time specific card used product specific product service sent survey single question would rather delivery service membership choice lower read full report problem company program like would take time example company could give month match mission brand card rest payment tech building far company working company create give give solution without favorite process business local student money product personal payment card built family use future matter card month per card per month model money different ways fee make every made card purchase cash back work cash back open product payment going getting clear success open product list public list team experience make product engineering technical head engineering time payment space need meet need team customer success team get every company customer success new help build future payment tech thank part contact
#
# ZETA
# face added bank bank added bank network first line code million card million company business hosting domain best engineering point view user high experience income use old tech credit modern credit mobile core card van management loan management retail credit card card key better cost income modern speed full machine modern product main tech modern enterprise payment opportunity annual note success million live bank quality life bank bank bank group money bank pay
#
# ZEVOY
# management financial authority business license limited valid throughout opportunity short management still green field market potential several still similar use team core finance product everything need build management company record time global less year pass across opportunity short game plan simple one management physical virtual apple pay pay credit via high credit little similar level credit institute secure cheap problem management time according per year growth share common solution simple card physical virtual credit apple pay pay solution simple mobile application view card solution simple user friendly view company forward model works better call new per month live taking share market west make better growth set limited amount large population education source team success team experience bank card industry well tech mon retail business building new leading business new leading business development professional experience high growth technology strong track record business business financial legal administration history building several digital strategy mobile management business development marketing strategy leading last position set digital various around product design house new value business risk management various various together current status team
#
# ZOEFINANCIAL
# financial want financial rather management data way process track number client profile client practice communication experience process place ensure quality work experience experience complete assessment market market size potential financial although become law consumer interest market independent near market back model low low fee per lead lead financial top ask team member team member team member team member team member team member found night day become partner game happy summary mission make better consumer click search advice rather sell male button focus rather
#
# 7BRIDGES
# need data master base forward air road major sea road production land change make today digital result marketing finance data rule based million single purpose every business access world class single access data technology need simply make need provide powered decision making management customer lower based global data making easy access end end data global supply network design order meet remove change management customer last band product value never look back high value data view global network making ever unique view customer needs create win win service industry improve service industry service access customer data network team data science engineering commercial first powered head engineering director data data science science world product management development head engineering head people head marketing engineering data science marketing tech marketing people management product marketing

# %%
display(master_df.reset_index().drop(columns = ["index"]))
# Out:
#                     Industry        Stage  \
# 0                       Tech     Series D
# 1              Entertainment   Late Stage
# 2                Real Estate   Late Stage
# 3     Travel and Hospitality     Pre-Seed
# 4      Media and Advertising  Early Stage
# ...                      ...          ...
# 1794              Enterprise         Seed
# 1795     Finance and Banking      SeriesC
# 1796     Finance and Banking      SeriesA
# 1797     Finance and Banking         Seed
# 1798                   Other         Seed
#
#                                   PDF URL  \
# 0                ./BestPitchPDFs/bolt.pdf
# 1             ./BestPitchPDFs/spotify.pdf
# 2              ./BestPitchPDFs/wework.pdf
# 3              ./BestPitchPDFs/airbnb.pdf
# 4            ./BestPitchPDFs/facebook.pdf
# ...                                   ...
# 1794       ./InsiderPitchPDFs/Zestful.pdf
# 1795          ./InsiderPitchPDFs/Zeta.pdf
# 1796         ./InsiderPitchPDFs/Zevoy.pdf
# 1797  ./InsiderPitchPDFs/ZoeFinancial.pdf
# 1798      ./InsiderPitchPDFs/7bridges.pdf
#
#                                          Processed Text
# 0     global network around powered one account sing...
# 1     computer science language idea like running wa...
# 2     space service community people new work fee po...
# 3     welcome book rather problem price important tr...
# 4     see directory user basis social school system ...
# ...                                                 ...
# 1794  membership card real time track real time proc...
# 1795  face added bank bank added bank network first ...
# 1796  management financial authority business licens...
# 1797  financial want financial rather management dat...
# 1798  need data master base forward air road major s...
#
# [1799 rows x 4 columns]

# %%
master_df.to_csv("./data/new_processed_pitch_data.csv")
